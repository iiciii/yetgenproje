# %%
import pandas as pd
import numpy as np
import time 
import random 

df = pd.read_excel("Tarot kart anlamları 2.csv")

class tarotcu_abla():

    def _init_(self, df):
        self.df = df

    def rastgeleCek(self,kartSayisi):
        return self.df.sample(n = kartSayisi)

    def tekKart(self,kartAdı):
        self.kartAdı = kartAdı
        kartDurum = 'TERS' if random.choice([True, False]) else 'DÜZ'
        print("Bir soru düşün ve kartın dediklerine güven!")
        print("Karıştırılıyor ve senin için bir kart çekiliyor...")
        time.sleep(3)
        print(f"kart : {kartAdı}['KARTIN ADI'] \n kart durumu: {kartDurum}['DURUM']")

        if kartDurum == "TERS":
                try:
                    if kategori.upper() == "GENEL":
                        print(f"genel: {self.df[(self.df['KARTIN ADI'] == kartAdı['KARTIN ADI']) & (self.df['DURUM'] == 'TERS')]['GENEL'].values[0]}")
                    elif kategori.upper() == "AŞK":
                        print(f"aşk: {self.df[(self.df['KARTIN ADI'] == kartAdı['KARTIN ADI']) & (self.df['DURUM'] == 'TERS')]['AŞK'].values[0]}")
                    elif kategori.upper() == "KARİYER":
                        print(f"genel: {self.df[(self.df['KARTIN ADI'] == kartAdı['KARTIN ADI']) & (self.df['DURUM'] == 'TERS')]['KARİYER'].values[0]}")
                    else:
                        raise NameError("lütfen belirtilen kategorilerden birini seçin!")
                except NameError as hata:
                    print(hata)

        else:
                try:
                    if kategori.upper() == "GENEL":
                        print(f"genel: {self.df[(self.df['KARTIN ADI'] == kartAdı['KARTIN ADI']) & (self.df['DURUM'] == 'DÜZ')]['GENEL'].values[0]}")
                    elif kategori.upper() == "AŞK":
                        print(f"aşk: {self.df[(self.df['KARTIN ADI'] == kartAdı['KARTIN ADI']) & (self.df['DURUM'] == 'DÜZ')]['AŞK'].values[0]}")
                    elif kategori.upper() == "KARİYER":
                        print(f"genel: {self.df[(self.df['KARTIN ADI'] == kartAdı['KARTIN ADI']) & (self.df['DURUM'] == 'DÜZ')]['KARİYER'].values[0]}")
                    else:
                        raise NameError("lütfen belirtilen kategorilerden birini seçin!")
                except NameError as hata:
                    print(hata)
                
        
    def ücKart(): 
        i = 0
        while i < 3:
            if i == 0:
               #  excelden geçmiş kartı çeiklir.
                print("Geçmiş kartı: ?????? ")
                i += 1
            if i == 1:
                # excelden şimdi kartı çeiklir.
                print("Şimdi kartı:  ?????")
                i += 1
            else:
                #  excelden gelecek kartı çeiklir.
                print("gelecek kartı:  ?????")
                i += 1

    def altıKart():
        i = 0
        while i < 6:
            if i == 0:
               #  excelden geçmiş kartı çeiklir.
                print("kendisi kartı: ?????? ")
                i += 1
            if i == 1:
                # excelden şimdi kartı çeiklir.
                print("aile kartı:  ?????")
                i += 1
            if i == 2:
                #  excelden gelecek kartı çeiklir.
                print("umdukları kartı:  ?????")
                i += 1
            if i == 3:
               #  excelden geçmiş kartı çeiklir.
                print("arkadaşları kartı: ?????? ")
                i += 1
            if i == 4:
                # excelden şimdi kartı çeiklir.
                print("korkuları kartı:  ?????")
                i += 1
            else:
                #  excelden gelecek kartı çeiklir.
                print("??? kartı:  ?????")
                i += 1



tarotcu_abla = tarotcu_abla()

print("""
TAROTÇU ABLA'YA HOŞ GELDİNİZ?
      
      Tek kart ---> kısa cevaplı sorular
      Üç kart ---> geçmiş/şimdi/gelecek
      Altı kart ---> kendi/arkadaşları/aile/umdukları/korkuların/???

      **çıkmak için 'q' ya basınız

      
      """)

kartSayisi = input("Çekilecek kart sayısını giriniz(sayı ile):")       #TRY-EXCEPT BLOĞU
kategori = input("Fal konusu seçiniz(GENEL/AŞK/KARİYER)")

while True:
    
    if (kartSayisi.lower == "q"):
        print("Fal baktırmadığınız için üzgünüz.")
        break
    elif (kartSayisi == "1"):
        tarotcu_abla.tekKart()
    elif (kartSayisi == "3"):
        tarotcu_abla.ücKart()
    elif (kartSayisi == "6"):
        tarotcu_abla.altıKart()
    else:
        print("Tarotçu Abla yanlış bir seçim yaptığını hissetti!!")
# Out:
# TAROTÇU ABLA'YA HOŞ GELDİNİZ?
#
#       Tek kart ---> kısa cevaplı sorular
#       Üç kart ---> geçmiş/şimdi/gelecek
#       Altı kart ---> kendi/arkadaşları/aile/umdukları/korkuların/???
#
#       **çıkmak için 'q' ya basınız
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 120
#     118     break
#     119 elif (kartSayisi == "1"):
# --> 120     tarotcu_abla.tekKart()
#     121 elif (kartSayisi == "3"):
#     122     tarotcu_abla.ücKart()
#
# Cell In[2], line 17, in tarotcu_abla.tekKart(self)
#      16 def tekKart(self):
# ---> 17     self.kartAdı = kartAdı
#      18     kartDurum = 'TERS' if random.choice([True, False]) else 'DÜZ'
#      19     print("Bir soru düşün ve kartın dediklerine güven!")
#
# NameError: name 'kartAdı' is not defined
